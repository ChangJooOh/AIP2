# %%
import numpy as np
from IPython.display import Image

# %% [markdown]
# #### Test 1
# Write a Python program that changes the positions of the two submatrix.
# (See figure.1-1, figrue.1-2 for detail)
# - Sample Output
# Original array:
# [[ 3.  3.  1.  1. ]
#  [ 3.  3.  1.  1. ]
#  [ 3.  3.  1.  1. ]
#  [ 1.  1.  2.  2. ]
#  [ 1.  1.  2.  2. ]
#  [ 1.  1.  2.  2. ]]
# reult in below:
# [[ 2.  2.  1.  1. ]
#  [ 2.  2.  1.  1. ]
#  [ 2.  2.  1.  1. ]
#  [ 1.  1.  3.  3. ]
#  [ 1.  1.  3.  3. ]
#  [ 1.  1.  3.  3. ]]

# %%
Image("Figure1.png")

# %%
# Original array
np_arr = np.array([[3,3,1,1],[3,3,1,1],[3,3,1,1],[1,1,2,2],[1,1,2,2],[1,1,2,2]])
print(np_arr)
# Out:
# [[3 3 1 1]
#  [3 3 1 1]
#  [3 3 1 1]
#  [1 1 2 2]
#  [1 1 2 2]
#  [1 1 2 2]]

# %%
#Write your code

# %% [markdown]
# #### Test 2
# - Use the np.arange() and np.reshape() functions to create a 3D array that is filled with 1 to 27. (See figure.2-1)
# - And multiply 2 only for the part marked in red and 3 for the part marked in blue. (See figure.2-2, figure.2-3 for detail)

# %%
Image("Figure2.png")

# %%
#Write your code

# %% [markdown]
# #### Test 3
# - Make a function that take two 2D arrays A and B as input parameters and returns a result C that matrix multiplication of two input.(See figure.3)
# - Do not use built-in numpy function like np.dot(But you can use it to validate your function.) and use default python function sum()
# (Hint: Use the np.shape to check the input array's shape)

# %%
Image("Figure3.png")

# %%
def matrixMultiple(A,B):
    C = np.empty((A.shape[0],B.shape[1]),dtype = np.int)
    #Write your code
    
    
    
    return C

# %%
A = np.array([[3,2,6,3],[2,3,1,5],[5,1,2,3]])
B = np.array([[2,3,1],[1,4,2],[3,1,1],[1,2,4]])

print(matrixMultiple(A,B))
print(np.dot(A,B))

assert (matrixMultiple(A,B) == np.dot(A,B)).all()
# Out:
# [[29 29 25]
#  [15 29 29]
#  [20 27 21]]
# [[29 29 25]
#  [15 29 29]
#  [20 27 21]]
